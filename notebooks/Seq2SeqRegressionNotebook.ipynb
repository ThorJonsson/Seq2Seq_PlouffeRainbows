# %%
import Seq2SeqRegression

# %% [markdown]
# First we load our data

# %%
X = Seq2SeqRegression.make_dataset('test.mat')

# %%
X['test']
# Out:
# array([[ 0.00111652,  0.0012186 ,  0.00128565, ..., -0.00263097,
#         -0.00265349, -0.00262848],
#        [ 0.0012186 ,  0.00128565,  0.00131788, ..., -0.00265349,
#         -0.00262848, -0.0025589 ],
#        [ 0.00128565,  0.00131788,  0.00131647, ..., -0.00262848,
#         -0.0025589 , -0.00244879],
#        ...,
#        [ 0.00040785,  0.00082022,  0.00125463, ..., -0.00300826,
#         -0.0026816 , -0.00232493],
#        [ 0.00082022,  0.00125463,  0.00169761, ..., -0.0026816 ,
#         -0.00232493, -0.0019474 ],
#        [ 0.00125463,  0.00169761,  0.00213506, ..., -0.00232493,
#         -0.0019474 , -0.0015587 ]])

# %%
Data = X['test']

# %% [markdown]
# The columns represent time in a chronological order and rows correspond to MUPS (Motor units potetional Signal)

# %%
Data[1].shape
# Out:
# (180,)

# %% [markdown]
# We consider using the sequence2sequence model as automatic feature extractor for the data. Each row in the data will be considered as an example that we will try to mimic with the neural network.

# %%
Data[0:5]
# Out:
# array([[  1.11651749e-03,   1.21859653e-03,   1.28565249e-03,
#           1.31787705e-03,   1.31646870e-03,   1.28354325e-03,
#           1.22203964e-03,   1.13559870e-03,   1.02840681e-03,
#           9.05010077e-04,   7.70169296e-04,   6.28687501e-04,
#           4.85253200e-04,   3.44259480e-04,   2.09700540e-04,
#           8.50516931e-05,  -2.68093397e-05,  -1.23687659e-04,
#          -2.04078267e-04,  -2.67166756e-04,  -3.12808111e-04,
#          -3.41484095e-04,  -3.54224315e-04,  -3.52491138e-04,
#          -3.38099447e-04,  -3.13086437e-04,  -2.79610008e-04,
#          -2.39787132e-04,  -1.95628548e-04,  -1.48907871e-04,
#          -1.01109106e-04,  -5.33097852e-05,  -6.18671389e-06,
#           4.00331528e-05,   8.55414095e-05,   1.30955859e-04,
#           1.77239495e-04,   2.25634747e-04,   2.77576160e-04,
#           3.34590219e-04,   3.98195720e-04,   4.69757717e-04,
#           5.50418354e-04,   6.40948437e-04,   7.41710388e-04,
# ...

# %%
import tensorflow as tf

# %%
tf.train.AdamOptimizer?

# %%
import Seq2SeqRegression
Seq2SeqRegression.train_MUPS_sequence_feature_extractor_copy()
# Out:
# Loss:   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-207a12f4d167> in <module>()
#       1 import Seq2SeqRegression
# ----> 2 Seq2SeqRegression.train_MUPS_sequence_feature_extractor_copy()
#
# /export/mlrg/tjonsson/Winter2017/DLFractalSequences/Seq2SeqRegression.pyc in train_MUPS_sequence_feature_extractor_copy()
#     214         Epoch = trange(1000, desc='Loss', leave=True)
#     215         for i in Epoch:
# --> 216             feed_dict = {encoder_input_ph: iterator.next_batch()}
#     217             start_time = time.time()
#     218             batch_loss,_ = session.run([loss, train_op], feed_dict)
#
# /export/mlrg/tjonsson/Winter2017/DLFractalSequences/Seq2SeqRegression.pyc in next_batch(self)
#      42
#      43     def next_batch(self):
# ...
